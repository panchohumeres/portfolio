# %%
import cv2
import os
import pandas as pd

# %%
def describe_images(folder):
    desc=[]
    for i in os.listdir(folder):
        image =folder+'/'+i
        img =  cv2.imread(image)
        height, width, depth = img.shape
        desc.append({'file':image,'w':width,'h':height,'aspect_ratio':height/width})
        
    desc=pd.DataFrame(desc)
    
    return desc
    #w=max(ws) #max width full stub images
    #h=max(hs) #max width full stub images

# %%
desc=describe_images('images/thumbs')

# %%
desc
# Out:
#                    file    w    h  aspect_ratio
# 0  images/thumbs/08.jpg  348  212      0.609195
# 1  images/thumbs/02.jpg  384  212      0.552083
# 2  images/thumbs/01.jpg  282  212      0.751773
# 3  images/thumbs/06.jpg  232  212      0.913793
# 4  images/thumbs/04.jpg  282  212      0.751773
# 5  images/thumbs/03.jpg  274  212      0.773723
# 6  images/thumbs/07.jpg  232  212      0.913793
# 7  images/thumbs/05.jpg  476  212      0.445378

# %%
describe_images('images/thumbs')
# Out:
#                    file    w    h  aspect_ratio
# 0  images/thumbs/08.jpg  348  212      0.609195
# 1  images/thumbs/02.jpg  384  212      0.552083
# 2  images/thumbs/01.jpg  282  212      0.751773
# 3  images/thumbs/06.jpg  232  212      0.913793
# 4  images/thumbs/04.jpg  282  212      0.751773
# 5  images/thumbs/03.jpg  274  212      0.773723
# 6  images/thumbs/07.jpg  232  212      0.913793
# 7  images/thumbs/05.jpg  476  212      0.445378

# %%
thumb_desc=describe_images('images/thumbs')

# %%
def resize(img,df):
    height, width, depth = img.shape
    aspect_ratio = height/width #actual aspect ratio
    print('original size ---> height: '+str(height)+' width: '+str(width))
    df=df.iloc[(df['aspect_ratio']-height).abs().argsort()[:1]] #closest aspect ratio
    w=df.w.iloc[0]
    h=df.h.iloc[0]
    if height>width:
        dimension = (int(h/aspect_ratio),h)
    else:
        dimension = (w,int(w*aspect_ratio))
    
    print('new size ---> height: '+str(dimension[0])+' width: '+str(dimension[1]))
    return cv2.resize(img, dimension)
    #return dimension

# %%
img =  cv2.imread('images/Francisco Humeres - Twitter Maps_files/kuala_lumpur-Malacca_st|1MM.jpeg')

# %%
def thumbnail(img,desc):
    df=desc.copy()
    height, width, depth = img.shape
    print('original image dim---> height:'+str(height)+' width: '+str(width))
    aspect_ratio = height/width #actual aspect ratio
    h=df.loc[0,'h'] #fixed height
    if width>height:
        w=df.loc[df['aspect_ratio'].idxmin(),'w'] #select row with higher aspect_radio, set new width to this value        
        if int(w*aspect_ratio)>h:
            dimension=(w,int(w*aspect_ratio))
        else:
            dimension=(int(h/aspect_ratio),h)
    else:
        w=df.loc[df['aspect_ratio'].idxmax(),'w'] #select row with lower aspect_radio, set new width to this value
        if int(w*aspect_ratio)>h:
            dimension=(w,int(w*aspect_ratio))
        else:
            dimension=(int(h/aspect_ratio),h)
    print(dimension)
    img=cv2.resize(img, dimension)
    height, width, depth = img.shape
    print('resized image dim---> height:'+str(height)+' width: '+str(width))    
    

    img=img[
            int(height/2)-int(h/2):int(height/2)+int(h/2),
    int(width/2)-int(w/2):int(width/2)+int(w/2)]
    height, width, depth = img.shape
    print('final thumbnail dim---> height:'+str(height)+' width: '+str(width))
    return img

# %%
#thumbnail(img,thumb_desc)

# %%
def show_image(image):
    if type(image)==str:
        img =  cv2.imread(image)
    else:
        img=image
    cv2.imshow("Original", img)
    cv2.waitKey(0)
    cv2.destroyWindow('Original')

# %%
path='images/fulls'

# %%
#show_image('images/Francisco Humeres - Twitter Maps_files/madrid___235K.png')

# %%
def caption(img,caption,x,y):
    height, width, depth = img.shape
    
    BLACK = (255,255,255)
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_size = 0.5
    font_color = BLACK
    font_thickness = 1
    text = caption
    x,y = int(width*x),int(height*y)
    img = cv2.putText(img, text, (x,y), font, font_size, font_color, font_thickness, cv2.LINE_AA)
    
    return img

# %%
def batch_resize(source='',target='',thumb_target='',thumb_model='',model='',cap=''):
    desc=describe_images(model)
    thumb_desc=describe_images(thumb_model)
    for i in os.listdir(source):
        image =source+'/'+i
        print('processing image:'+image)
        img =  cv2.imread(image)
        
        print('generating thumbnail')
        thumb=thumbnail(img,thumb_desc)
        
        print('resizing image')
        img=resize(img,desc)

        print('adding caption')
        img=caption(img,cap,0.07,0.95)
        print('saving file '+target+'/'+i)
        cv2.imwrite(target+'/'+i,img)
        print('saving file '+thumb_target+'/'+i)
        cv2.imwrite(thumb_target+'/'+i,thumb)

# %%
batch_resize(thumb_target='images/tmp/thumbs',thumb_model='images/thumbs',source='images/Francisco Humeres - Twitter Maps_files',target='images/tmp/fulls',model='images/fulls',cap='(c) 2013-14 Francisco J. Humeres M.')
# Out:
# processing image:images/Francisco Humeres - Twitter Maps_files/glasgow-edinburgh|250K.jpeg
# generating thumbnail
# original image dim---> height:2716 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2716 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/glasgow-edinburgh|250K.jpeg
# saving file images/tmp/thumbs/glasgow-edinburgh|250K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/jakarta|2.5MM.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/jakarta|2.5MM.png
# saving file images/tmp/thumbs/jakarta|2.5MM.png
# processing image:images/Francisco Humeres - Twitter Maps_files/new_orleans-baton_rouge|.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/new_orleans-baton_rouge|.jpeg
# saving file images/tmp/thumbs/new_orleans-baton_rouge|.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/san_francisco-bay_area|290K.png
# generating thumbnail
# original image dim---> height:2967 width: 3840
# (476, 367)
# resized image dim---> height:367 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2967 width: 3840
# new size ---> height: 525 width: 405
# adding caption
# saving file images/tmp/fulls/san_francisco-bay_area|290K.png
# saving file images/tmp/thumbs/san_francisco-bay_area|290K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/istanbul|800K.png
# generating thumbnail
# original image dim---> height:2967 width: 3840
# (476, 367)
# resized image dim---> height:367 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2967 width: 3840
# new size ---> height: 525 width: 405
# adding caption
# saving file images/tmp/fulls/istanbul|800K.png
# saving file images/tmp/thumbs/istanbul|800K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/kuala_lumpur-Malacca_st|1MM.jpeg
# generating thumbnail
# original image dim---> height:1422 width: 3840
# (572, 212)
# resized image dim---> height:212 width: 572
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1422 width: 3840
# new size ---> height: 525 width: 194
# adding caption
# saving file images/tmp/fulls/kuala_lumpur-Malacca_st|1MM.jpeg
# saving file images/tmp/thumbs/kuala_lumpur-Malacca_st|1MM.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/singapore-batam|265K.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/singapore-batam|265K.png
# saving file images/tmp/thumbs/singapore-batam|265K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/detroit|470K.jpeg
# generating thumbnail
# original image dim---> height:2716 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2716 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/detroit|470K.jpeg
# saving file images/tmp/thumbs/detroit|470K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/new_york-new_jersey-philadelphia|2MM.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/new_york-new_jersey-philadelphia|2MM.png
# saving file images/tmp/thumbs/new_york-new_jersey-philadelphia|2MM.png
# processing image:images/Francisco Humeres - Twitter Maps_files/johannesburg|100K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/johannesburg|100K.jpeg
# saving file images/tmp/thumbs/johannesburg|100K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/manila|500K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/manila|500K.jpeg
# saving file images/tmp/thumbs/manila|500K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/manchester-liverpool|400K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/manchester-liverpool|400K.jpeg
# saving file images/tmp/thumbs/manchester-liverpool|400K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/lower_countries|570K.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/lower_countries|570K.png
# saving file images/tmp/thumbs/lower_countries|570K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/mumbai|32K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/mumbai|32K.jpeg
# saving file images/tmp/thumbs/mumbai|32K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/rhur-rhein|30K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/rhur-rhein|30K.jpeg
# saving file images/tmp/thumbs/rhur-rhein|30K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/portugal|290K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 1920
# (232, 328)
# resized image dim---> height:328 width: 232
# final thumbnail dim---> height:212 width: 232
# resizing image
# original size ---> height: 2715 width: 1920
# new size ---> height: 371 width: 525
# adding caption
# saving file images/tmp/fulls/portugal|290K.jpeg
# saving file images/tmp/thumbs/portugal|290K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/buenos_aires-la_plata|380K.png
# generating thumbnail
# original image dim---> height:2967 width: 3840
# (476, 367)
# resized image dim---> height:367 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2967 width: 3840
# new size ---> height: 525 width: 405
# adding caption
# saving file images/tmp/fulls/buenos_aires-la_plata|380K.png
# saving file images/tmp/thumbs/buenos_aires-la_plata|380K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/toronto-buffalo|300K.png
# generating thumbnail
# original image dim---> height:2232 width: 3840
# (476, 276)
# resized image dim---> height:276 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2232 width: 3840
# new size ---> height: 525 width: 305
# adding caption
# saving file images/tmp/fulls/toronto-buffalo|300K.png
# saving file images/tmp/thumbs/toronto-buffalo|300K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/osaka-kobe|450K.jpeg
# generating thumbnail
# original image dim---> height:2716 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2716 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/osaka-kobe|450K.jpeg
# saving file images/tmp/thumbs/osaka-kobe|450K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/tokio-yokohama|2MM.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/tokio-yokohama|2MM.png
# saving file images/tmp/thumbs/tokio-yokohama|2MM.png
# processing image:images/Francisco Humeres - Twitter Maps_files/chicago|500K.png
# generating thumbnail
# original image dim---> height:2967 width: 3840
# (476, 367)
# resized image dim---> height:367 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2967 width: 3840
# new size ---> height: 525 width: 405
# adding caption
# saving file images/tmp/fulls/chicago|500K.png
# saving file images/tmp/thumbs/chicago|500K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/dubai|105K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/dubai|105K.jpeg
# saving file images/tmp/thumbs/dubai|105K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/dallas|560K.jpeg
# generating thumbnail
# original image dim---> height:2716 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2716 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/dallas|560K.jpeg
# saving file images/tmp/thumbs/dallas|560K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/las_vegas|190K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/las_vegas|190K.jpeg
# saving file images/tmp/thumbs/las_vegas|190K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/madrid|235K.png
# generating thumbnail
# original image dim---> height:2967 width: 3840
# (476, 367)
# resized image dim---> height:367 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2967 width: 3840
# new size ---> height: 525 width: 405
# adding caption
# saving file images/tmp/fulls/madrid|235K.png
# saving file images/tmp/thumbs/madrid|235K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/paris|500K.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/paris|500K.png
# saving file images/tmp/thumbs/paris|500K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/boston|190K.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/boston|190K.png
# saving file images/tmp/thumbs/boston|190K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/mexico_city|350K.png
# generating thumbnail
# original image dim---> height:2967 width: 3840
# (476, 367)
# resized image dim---> height:367 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2967 width: 3840
# new size ---> height: 525 width: 405
# adding caption
# saving file images/tmp/fulls/mexico_city|350K.png
# saving file images/tmp/thumbs/mexico_city|350K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/milan-lombardy|100K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/milan-lombardy|100K.jpeg
# saving file images/tmp/thumbs/milan-lombardy|100K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/los_angeles|500K.png
# generating thumbnail
# original image dim---> height:1356 width: 1920
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1356 width: 1920
# new size ---> height: 525 width: 370
# adding caption
# saving file images/tmp/fulls/los_angeles|500K.png
# saving file images/tmp/thumbs/los_angeles|500K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/vancouver-seattle|295K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/vancouver-seattle|295K.jpeg
# saving file images/tmp/thumbs/vancouver-seattle|295K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/london|500K.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/london|500K.png
# saving file images/tmp/thumbs/london|500K.png
# processing image:images/Francisco Humeres - Twitter Maps_files/sao_paulo|1.2MM.png
# generating thumbnail
# original image dim---> height:1891 width: 3840
# (476, 234)
# resized image dim---> height:234 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 1891 width: 3840
# new size ---> height: 525 width: 258
# adding caption
# saving file images/tmp/fulls/sao_paulo|1.2MM.png
# saving file images/tmp/thumbs/sao_paulo|1.2MM.png
# processing image:images/Francisco Humeres - Twitter Maps_files/palestine-israel|150K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/palestine-israel|150K.jpeg
# saving file images/tmp/thumbs/palestine-israel|150K.jpeg
# processing image:images/Francisco Humeres - Twitter Maps_files/miami-florida|375K.jpeg
# generating thumbnail
# original image dim---> height:2715 width: 3840
# (476, 336)
# resized image dim---> height:336 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 2715 width: 3840
# new size ---> height: 525 width: 371
# adding caption
# saving file images/tmp/fulls/miami-florida|375K.jpeg
# saving file images/tmp/thumbs/miami-florida|375K.jpeg
