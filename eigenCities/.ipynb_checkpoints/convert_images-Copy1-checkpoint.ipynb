# %%
import cv2
import os
import pandas as pd

# %%
def describe_images(folder):
    desc=[]
    for i in os.listdir(folder):
        image =folder+'/'+i
        img =  cv2.imread(image)
        height, width, depth = img.shape
        desc.append({'file':image,'w':width,'h':height,'aspect_ratio':height/width})
        
    desc=pd.DataFrame(desc)
    
    return desc
    #w=max(ws) #max width full stub images
    #h=max(hs) #max width full stub images

# %%
desc=describe_images('images/thumbs')

# %%
desc
# Out:
#                     file    w    h  aspect_ratio
# 0   images/thumbs/12.jpg  360  225         0.625
# 1   images/thumbs/08.jpg  360  225         0.625
# 2   images/thumbs/02.jpg  360  225         0.625
# 3   images/thumbs/01.jpg  360  225         0.625
# 4   images/thumbs/06.jpg  360  225         0.625
# 5   images/thumbs/09.jpg  360  225         0.625
# 6   images/thumbs/04.jpg  360  225         0.625
# 7   images/thumbs/03.jpg  360  225         0.625
# 8   images/thumbs/07.jpg  360  225         0.625
# 9   images/thumbs/11.jpg  360  225         0.625
# 10  images/thumbs/05.jpg  360  225         0.625
# 11  images/thumbs/10.jpg  360  225         0.625

# %%
thumb_desc=describe_images('images/thumbs')

# %%
def resize(img,df):
    height, width, depth = img.shape
    aspect_ratio = height/width #actual aspect ratio
    print('original size ---> height: '+str(height)+' width: '+str(width))
    df=df.iloc[(df['aspect_ratio']-height).abs().argsort()[:1]] #closest aspect ratio
    w=df.w.iloc[0]
    h=df.h.iloc[0]
    if height>width:
        dimension = (int(h/aspect_ratio),h)
    else:
        dimension = (w,int(w*aspect_ratio))
    
    print('new size ---> height: '+str(dimension[0])+' width: '+str(dimension[1]))
    return cv2.resize(img, dimension)
    #return dimension

# %%
img =  cv2.imread('images/Francisco Humeres - Twitter Maps_files/kuala_lumpur-Malacca_st|1MM.jpeg')

# %%
def thumbnail(img,desc):
    df=desc.copy()
    height, width, depth = img.shape
    print('original image dim---> height:'+str(height)+' width: '+str(width))
    aspect_ratio = height/width #actual aspect ratio
    h=df.loc[0,'h'] #fixed height
    if width>height:
        w=df.loc[df['aspect_ratio'].idxmin(),'w'] #select row with higher aspect_radio, set new width to this value        
        if int(w*aspect_ratio)>h:
            dimension=(w,int(w*aspect_ratio))
        else:
            dimension=(int(h/aspect_ratio),h)
    else:
        w=df.loc[df['aspect_ratio'].idxmax(),'w'] #select row with lower aspect_radio, set new width to this value
        if int(w*aspect_ratio)>h:
            dimension=(w,int(w*aspect_ratio))
        else:
            dimension=(int(h/aspect_ratio),h)
    print(dimension)
    img=cv2.resize(img, dimension)
    height, width, depth = img.shape
    print('resized image dim---> height:'+str(height)+' width: '+str(width))    
    

    img=img[
            int(height/2)-int(h/2):int(height/2)+int(h/2),
    int(width/2)-int(w/2):int(width/2)+int(w/2)]
    height, width, depth = img.shape
    print('final thumbnail dim---> height:'+str(height)+' width: '+str(width))
    return img

# %%
#thumbnail(img,thumb_desc)

# %%
def show_image(image):
    if type(image)==str:
        img =  cv2.imread(image)
    else:
        img=image
    cv2.imshow("Original", img)
    cv2.waitKey(0)
    cv2.destroyWindow('Original')

# %%
path='images/fulls'

# %%
#show_image('images/Francisco Humeres - Twitter Maps_files/madrid___235K.png')

# %%
def caption(img,caption,x,y):
    height, width, depth = img.shape
    
    BLACK = (255,255,255)
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_size = 0.5
    font_color = BLACK
    font_thickness = 1
    text = caption
    x,y = int(width*x),int(height*y)
    img = cv2.putText(img, text, (x,y), font, font_size, font_color, font_thickness, cv2.LINE_AA)
    
    return img

# %%
def batch_resize(source='',target='',thumb_target='',thumb_model='',model='',cap=''):
    desc=describe_images(model)
    thumb_desc=describe_images(thumb_model)
    for i in os.listdir(source):
        image =source+'/'+i
        print('processing image:'+image)
        img =  cv2.imread(image)
        
        print('generating thumbnail')
        thumb=thumbnail(img,thumb_desc)
        
        print('resizing image')
        img=resize(img,desc)

        print('adding caption')
        img=caption(img,cap,0.07,0.95)
        print('saving file '+target+'/'+i)
        cv2.imwrite(target+'/'+i,img)
        print('saving file '+thumb_target+'/'+i)
        cv2.imwrite(thumb_target+'/'+i,thumb)

# %%
batch_resize(thumb_target='images/tmp_rythms/thumbs',thumb_model='images/thumbs',source='images/Francisco Humeres - Tweeting Rythms_files',target='images/tmp_rythms/fulls',model='images/fulls',cap='(c) 2013-14 Francisco J. Humeres M.')
# Out:
# processing image:images/Francisco Humeres - Tweeting Rythms_files/minneapolis-st_paul.png
# generating thumbnail
# original image dim---> height:640 width: 774
# (476, 393)
# resized image dim---> height:393 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 640 width: 774
# new size ---> height: 525 width: 434
# adding caption
# saving file images/tmp_rythms/fulls/minneapolis-st_paul.png
# saving file images/tmp_rythms/thumbs/minneapolis-st_paul.png
# processing image:images/Francisco Humeres - Tweeting Rythms_files/lower_countries|570K.png
# generating thumbnail
# original image dim---> height:650 width: 847
# (476, 365)
# resized image dim---> height:365 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 650 width: 847
# new size ---> height: 525 width: 402
# adding caption
# saving file images/tmp_rythms/fulls/lower_countries|570K.png
# saving file images/tmp_rythms/thumbs/lower_countries|570K.png
# processing image:images/Francisco Humeres - Tweeting Rythms_files/buenos_aires-la_plata|380K.png
# generating thumbnail
# original image dim---> height:420 width: 560
# (476, 357)
# resized image dim---> height:357 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 420 width: 560
# new size ---> height: 525 width: 393
# adding caption
# saving file images/tmp_rythms/fulls/buenos_aires-la_plata|380K.png
# saving file images/tmp_rythms/thumbs/buenos_aires-la_plata|380K.png
# processing image:images/Francisco Humeres - Tweeting Rythms_files/toronto-buffalo|300K.png
# generating thumbnail
# original image dim---> height:533 width: 751
# (476, 337)
# resized image dim---> height:337 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 533 width: 751
# new size ---> height: 525 width: 372
# adding caption
# saving file images/tmp_rythms/fulls/toronto-buffalo|300K.png
# saving file images/tmp_rythms/thumbs/toronto-buffalo|300K.png
# processing image:images/Francisco Humeres - Tweeting Rythms_files/chicago|500K.png
# generating thumbnail
# original image dim---> height:650 width: 781
# (476, 396)
# resized image dim---> height:396 width: 476
# final thumbnail dim---> height:212 width: 476
# resizing image
# original size ---> height: 650 width: 781
# new size ---> height: 525 width: 436
# adding caption
# saving file images/tmp_rythms/fulls/chicago|500K.png
# saving file images/tmp_rythms/thumbs/chicago|500K.png
